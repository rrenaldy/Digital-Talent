# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# 1. Prepare a list of offices sorted by country, state, and city

# %%
run("SELECT * FROM offices ORDER BY country,state,city")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# 2. How many employees are there in the company?

# %%
run("""
SELECT
    officeCode,
    COUNT(*) AS JumlahPegawai
FROM
    employees
GROUP BY
    officeCOde
""")
# Out:
#   officeCode  JumlahPegawai
# 0          1              6
# 1          2              2
# 2          3              2
# 3          4              5
# 4          5              2
# 5          6              4
# 6          7              2

# %% [markdown]
# 3. What is the total of payments received?

# %%
run("""
SELECT
    SUM(amount) AS TotalPembayaran
FROM
    payments
""")
# Out:
#    TotalPembayaran
# 0       8853839.23

# %% [markdown]
# 4. List the product lines that contain 'Cars'.

# %%
run("""
SELECT 
    *
FROM
    products
WHERE
    productline LIKE '%cars%'
""")
# Out:
#    productCode                                productName   productLine  \
# 0     S10_1949                   1952 Alpine Renault 1300  Classic Cars
# 1     S10_4757                        1972 Alfa Romeo GTA  Classic Cars
# 2     S10_4962                     1962 LanciaA Delta 16V  Classic Cars
# 3     S12_1099                          1968 Ford Mustang  Classic Cars
# 4     S12_1108                          2001 Ferrari Enzo  Classic Cars
# 5     S12_3148                         1969 Corvair Monza  Classic Cars
# 6     S12_3380                         1968 Dodge Charger  Classic Cars
# 7     S12_3891                           1969 Ford Falcon  Classic Cars
# 8     S12_3990                    1970 Plymouth Hemi Cuda  Classic Cars
# 9     S12_4675                         1969 Dodge Charger  Classic Cars
# 10    S18_1129                            1993 Mazda RX-7  Classic Cars
# 11    S18_1342                       1937 Lincoln Berline  Vintage Cars
# ...

# %% [markdown]
# 5. Report total payments for October 28, 2004.

# %%
run("""
SELECT
    DATE(paymentDate) AS Tanggal,
    SUM(amount) AS TotalPembayaran
FROM
    payments
WHERE
    paymentDate='2004-10-28'
""")
# Out:
#       Tanggal  TotalPembayaran
# 0  2004-10-28         47411.33

# %% [markdown]
# 6. Report those payments greater than \$100,000.

# %%
run("""
SELECT 
    *
FROM
    payments 
WHERE
    amount>"100000"
ORDER BY
    amount DESC
""")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             141    JE105477  2005-03-18  120166.58
# 1             141     ID10962  2004-12-31  116208.40
# 2             124    KI131716  2003-08-15  111654.40
# 3             148    KM172879  2003-12-26  105743.00
# 4             124    AE215433  2005-03-05  101244.59

# %% [markdown]
# 7. List the products in each product line.

# %%
run("""
SELECT
    productNAme,
    productLine
FROM
    products
ORDER BY
    productLine,
    productName
""")
# Out:
#                                      productNAme       productLine
# 0                    1948 Porsche 356-A Roadster      Classic Cars
# 1                 1948 Porsche Type 356 Roadster      Classic Cars
# 2                             1949 Jaguar XK 120      Classic Cars
# 3                       1952 Alpine Renault 1300      Classic Cars
# 4                              1952 Citroen-15CV      Classic Cars
# 5                        1956 Porsche 356A Coupe      Classic Cars
# 6                      1957 Corvette Convertible      Classic Cars
# 7                          1957 Ford Thunderbird      Classic Cars
# 8            1958 Chevy Corvette Limited Edition      Classic Cars
# 9                          1961 Chevrolet Impala      Classic Cars
# 10                        1962 LanciaA Delta 16V      Classic Cars
# 11                         1965 Aston Martin DB5      Classic Cars
# 12                     1966 Shelby Cobra 427 S/C      Classic Cars
# ...

# %% [markdown]
# 8. How many products in each product line?

# %%
run("""
SELECT
    DISTINCT(productLine),
    COUNT(productLine) AS JumlahProduk
FROM
    products
GROUP BY
    productline
""")
# Out:
#         productLine  JumlahProduk
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %% [markdown]
# 9. What is the minimum payment received?

# %%
run("""
SELECT 
   customerNumber,
   CheckNumber,
   paymentDate,
   MIN(amount) AS PembayaranTerendah
FROM
    payments
""")

# %% [markdown]
# 10. List all payments greater than twice the average payment.

# %%
run("""
SELECT 
    *
FROM
    payments
WHERE
    amount > 2 * (select AVG(amount) from payments)
ORDER BY
    amount DESC
""")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              141    JE105477  2005-03-18  120166.58
# 1              141     ID10962  2004-12-31  116208.40
# 2              124    KI131716  2003-08-15  111654.40
# 3              148    KM172879  2003-12-26  105743.00
# 4              124    AE215433  2005-03-05  101244.59
# 5              321     DJ15149  2003-11-03   85559.12
# 6              124    BG255406  2004-08-28   85410.87
# 7              167    GN228846  2003-12-03   85024.46
# 8              124     ET64396  2005-04-16   83598.04
# 9              114    MA765515  2004-12-15   82261.22
# 10             239    NQ865547  2004-03-15   80375.24
# 11             323    AL493079  2005-05-23   75020.13
# 12             141    IN446258  2005-03-25   65071.26

# %% [markdown]
# 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("""
SELECT 
    AVG(((MSRP-buyPrice)/buyPrice)*100) AS RataRataPersentase
FROM
    products
""")
# Out:
#    RataRataPersentase
# 0           88.702392

# %% [markdown]
# 12. How many distinct products does ClassicModels sell?

# %%
run("""
SELECT
    COUNT(productCode) AS JumlahProduk
FROM
    products
""")
# Out:
#    JumlahProduk
# 0           110

# %% [markdown]
# 13. Report the name and city of customers who don't have sales representatives?

# %%
run("""
SELECT
    customerName,
    city,
    salesRepEmployeeNumber
FROM
    customers
WHERE
    salesRepEmployeeNumber is null
ORDER BY
    city
""")
# Out:
#                       customerName              city salesRepEmployeeNumber
# 0                 Warburg Exchange            Aachen                   None
# 1                 Schuyler Imports         Amsterdam                   None
# 2                 Der Hund Imports            Berlin                   None
# 3        Cramer Spezialitäten, Ltd       Brandenburg                   None
# 4            Asian Treasures, Inc.              Cork                   None
# 5                  Natürlich Autos         Cunewalde                   None
# 6         Messner Shopping Network         Frankfurt                   None
# 7                BG&E Collectables          Fribourg                   None
# 8             SAR Distributors, Co          Hatfield                   None
# 9               Raanan Stores, Inc           Herzlia                   None
# 10        Feuer Online Stores, Inc           Leipzig                   None
# ...

# %% [markdown]
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("""
SELECT
    CONCAT(firstName," ",lastName) AS Nama,
    jobTitle
FROM
    employees
WHERE jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%' 
""")
# Out:
#                 Nama              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# 15. Which orders have a value greater than $5,000?

# %%
run("""
SELECT
    orderNumber,
    SUM(quantityOrdered*priceEach) AS Total
FROM
    orderdetails
WHERE
    (quantityOrdered*priceEach)>5000
GROUP BY
    orderNumber
ORDER BY
    Total
""")
# Out:
#      orderNumber     Total
# 0          10418   5000.50
# 1          10209   5038.80
# 2          10292   5055.60
# 3          10337   5067.00
# 4          10389   5071.50
# 5          10393   5076.40
# 6          10129   5087.70
# 7          10148   5088.22
# 8          10193   5090.36
# 9          10137   5092.12
# 10         10279   5129.76
# 11         10396   5138.76
# 12         10356   5173.33
# 13         10218   5181.94
# 14         10168   5184.00
# 15         10232   5200.76
# 16         10157   5239.68
# 17         10243   5257.89
# 18         10155   5273.26
# 19         10340   5273.95
# 20         10296   5279.40
# 21         10123   5282.64
# 22         10307   5288.79
# 23         10273   5293.50
# 24         10274   5301.71
# 25         10149   5317.60
# 26         10197   5324.40
# 27         10402   5352.30
# 28         10202   5374.57
# 29         10319   5423.85
# ..           ...       ...
# 191        10263  19389.16
# 192        10117  19560.25
# ...
